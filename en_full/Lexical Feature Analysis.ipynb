# %%
import csv

headers = ['name','eatType','priceRange', 'customer rating', 'near', 'food', 'area','familyFriendly']

trainset_reader = csv.DictReader(open('trainset.csv', encoding='utf-8', mode='rt'))

feature_list = []
sentences = []
foods = set()
for row in trainset_reader:
    i1 = row['mr']
    i2 = row['ref']
    kv = {}
    keywords = i1.split(',')
    for keyword in keywords:
        kidx = keyword.find('[')
        key = keyword[:kidx].strip()
        value = keyword[kidx + 1: keyword.find(']')]
        kv[key] = value
        if key == 'food':
            foods.add(value)
        
    feature_list.append(kv)
    sentences.append(i2)

len(sentences)
# Out:
# 42061

# %%
lex_feature_reader = csv.DictReader(open('train_lex_features.csv', encoding='utf-8', mode='rt'), delimiter='\t')
lex_feature_list = []
for row in lex_feature_reader:
    nsentences = row['Number Of Sentences']
    fwords = row['First Words']
    fpostags = row['First POS tags']
    fphrases = row['First Phrases']
    
    fv = {}
    fv['nsentences'] = nsentences
    fv['fwords'] = fwords
    fv['fpostags'] = fpostags
    fv['fphrases'] = fphrases
    lex_feature_list.append(fv)
    
lex_feature_list
# Out:
# [{'fphrases': 'NP,NP',
#   'fpostags': 'NNP,NNS',
#   'fwords': 'XNAMEX,Prices',
#   'nsentences': '2'},
#  {'fphrases': 'ADJP,NP',
#   'fpostags': 'RB,NNP',
#   'fwords': 'Close,Delicious',
#   'nsentences': '2'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'VP', 'fpostags': 'VBN', 'fwords': 'Located', 'nsentences': '1'},
#  {'fphrases': 'PP', 'fpostags': 'IN', 'fwords': 'For', 'nsentences': '1'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,PRP',
#   'fwords': 'XNAMEX,You',
#   'nsentences': '2'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP,NP,NP,NP',
#   'fpostags': 'NNP,PRP,NNS,PRP',
#   'fwords': 'XNAMEX,It,Prices,It',
#   'nsentences': '4'},
#  {'fphrases': 'PP', 'fpostags': 'IN', 'fwords': 'In', 'nsentences': '1'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,PRP',
#   'fwords': 'XNAMEX,They',
#   'nsentences': '2'},
#  {'fphrases': 'PP,NP',
#   'fpostags': 'IN,PRP',
#   'fwords': 'In,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP', 'fpostags': 'DT', 'fwords': 'A', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'PP,NP',
#   'fpostags': 'IN,DT',
#   'fwords': 'For,The',
#   'nsentences': '2'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,PRP',
#   'fwords': 'XNAMEX,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'Yippee', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,PRP$',
#   'fwords': 'XNAMEX,Their',
#   'nsentences': '2'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'DT,PRP',
#   'fwords': 'An,It',
#   'nsentences': '2'},
#  {'fphrases': 'PP', 'fpostags': 'IN', 'fwords': 'Near', 'nsentences': '1'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,DT',
#   'fwords': 'XNAMEX,The',
#   'nsentences': '2'},
#  {'fphrases': 'NP', 'fpostags': 'NN', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'EX,PRP',
#   'fwords': 'There,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,PRP',
#   'fwords': 'XNAMEX,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,PRP',
#   'fwords': 'XNAMEX,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,PRP',
#   'fwords': 'XNAMEX,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP', 'fpostags': 'DT', 'fwords': 'A', 'nsentences': '1'},
#  {'fphrases': 'VP', 'fpostags': 'VBN', 'fwords': 'Located', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'DT', 'fwords': 'A', 'nsentences': '1'},
#  {'fphrases': 'NP,NP,NP',
#   'fpostags': 'NNP,PRP,PRP',
#   'fwords': 'XNAMEX,It,It',
#   'nsentences': '3'},
#  {'fphrases': 'NP,NP,NP',
#   'fpostags': 'NNP,PRP,PRP',
#   'fwords': 'XNAMEX,It,It',
#   'nsentences': '3'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'PP', 'fpostags': 'IN', 'fwords': 'In', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,PRP',
#   'fwords': 'XNAMEX,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP,NP,NP',
#   'fpostags': 'NNP,DT,PRP',
#   'fwords': 'XNAMEX,The,It',
#   'nsentences': '3'},
#  {'fphrases': 'PP', 'fpostags': 'IN', 'fwords': 'On', 'nsentences': '1'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,PRP',
#   'fwords': 'XNAMEX,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,PRP',
#   'fwords': 'XNAMEX,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP', 'fpostags': 'JJ', 'fwords': 'Italian', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'EX', 'fwords': 'There', 'nsentences': '1'},
#  {'fphrases': 'PP', 'fpostags': 'IN', 'fwords': 'For', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'DT', 'fwords': 'A', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'EX', 'fwords': 'There', 'nsentences': '1'},
#  {'fphrases': 'NP,NP,NP',
#   'fpostags': 'DT,PRP,PRP',
#   'fwords': 'A,It,It',
#   'nsentences': '3'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'PP,NP',
#   'fpostags': 'IN,PRP',
#   'fwords': 'Near,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,PRP',
#   'fwords': 'XNAMEX,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'EX,PRP',
#   'fwords': 'There,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,PRP',
#   'fwords': 'North,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'DT,PRP',
#   'fwords': 'The,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,PRP',
#   'fwords': 'XNAMEX,It',
#   'nsentences': '2'},
#  {'fphrases': 'PP', 'fpostags': 'IN', 'fwords': 'In', 'nsentences': '1'},
#  {'fphrases': 'NP,NP,NP',
#   'fpostags': 'NNP,PRP,DT',
#   'fwords': 'XNAMEX,They,The',
#   'nsentences': '3'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,PRP',
#   'fwords': 'XNAMEX,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'DT,PRP$',
#   'fwords': 'A,its',
#   'nsentences': '2'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,PRP',
#   'fwords': 'XNAMEX,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,DT',
#   'fwords': 'XNAMEX,no',
#   'nsentences': '2'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'PP,NP',
#   'fpostags': 'IN,PRP',
#   'fwords': 'In,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,PRP',
#   'fwords': 'XNAMEX,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,PRP',
#   'fwords': 'XNAMEX,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,PRP',
#   'fwords': 'XNAMEX,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP',
#   'fpostags': 'NNP',
#   'fwords': 'Children',
#   'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'UCP', 'fpostags': 'NN', 'fwords': 'wine', 'nsentences': '1'},
#  {'fphrases': 'PP,NP',
#   'fpostags': 'IN,DT',
#   'fwords': 'Near,The',
#   'nsentences': '2'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,PRP',
#   'fwords': 'XNAMEX,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,PRP',
#   'fwords': 'XNAMEX,It',
#   'nsentences': '2'},
#  {'fphrases': 'PP', 'fpostags': 'IN', 'fwords': 'With', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,PRP',
#   'fwords': 'XNAMEX,It',
#   'nsentences': '2'},
#  {'fphrases': 'VP', 'fpostags': 'VBN', 'fwords': 'Located', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,PRP',
#   'fwords': 'XNAMEX,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,PRP',
#   'fwords': 'XNAMEX,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'EX,PRP',
#   'fwords': 'There,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'PP,NP',
#   'fpostags': 'IN,NN',
#   'fwords': 'for,price',
#   'nsentences': '2'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'PP', 'fpostags': 'IN', 'fwords': 'Near', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'EX', 'fwords': 'There', 'nsentences': '1'},
#  {'fphrases': 'VP,FRAG',
#   'fpostags': 'VBG,RB',
#   'fwords': 'Serving,Not',
#   'nsentences': '2'},
#  {'fphrases': 'NP', 'fpostags': 'EX', 'fwords': 'There', 'nsentences': '1'},
#  {'fphrases': 'PP', 'fpostags': 'IN', 'fwords': 'Near', 'nsentences': '1'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'DT,PRP',
#   'fwords': 'The,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP,NP,NP',
#   'fpostags': 'NNP,PRP,PRP',
#   'fwords': 'XNAMEX,It,You',
#   'nsentences': '3'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,NNS',
#   'fwords': 'Located,Families',
#   'nsentences': '2'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,DT',
#   'fwords': 'XNAMEX,This',
#   'nsentences': '2'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'DT', 'fwords': 'The', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'DT', 'fwords': 'The', 'nsentences': '1'},
#  {'fphrases': 'NP,NP,NP',
#   'fpostags': 'NNP,PRP,PRP',
#   'fwords': 'XNAMEX,It,It',
#   'nsentences': '3'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'EX', 'fwords': 'There', 'nsentences': '1'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,NN',
#   'fwords': 'XNAMEX,Customer',
#   'nsentences': '2'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'VP', 'fpostags': 'VBN', 'fwords': 'Located', 'nsentences': '1'},
#  {'fphrases': 'VP', 'fpostags': 'VBN', 'fwords': 'Located', 'nsentences': '1'},
#  {'fphrases': 'ADJP',
#   'fpostags': 'RB',
#   'fwords': 'moderately',
#   'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'PP', 'fpostags': 'IN', 'fwords': 'With', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'EX', 'fwords': 'There', 'nsentences': '1'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,PRP',
#   'fwords': 'XNAMEX,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,PRP',
#   'fwords': 'XNAMEX,It',
#   'nsentences': '2'},
#  {'fphrases': 'PP', 'fpostags': 'IN', 'fwords': 'Near', 'nsentences': '1'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,PRP',
#   'fwords': 'XNAMEX,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'JJ', 'fwords': 'XNAMEXs', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'SBAR', 'fpostags': 'IN', 'fwords': 'If', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'DT,PRP',
#   'fwords': 'The,They',
#   'nsentences': '2'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,DT',
#   'fwords': 'XNAMEX,This',
#   'nsentences': '2'},
#  {'fphrases': 'PP', 'fpostags': 'IN', 'fwords': 'In', 'nsentences': '1'},
#  {'fphrases': 'PP', 'fpostags': 'IN', 'fwords': 'At', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'VP',
#   'fpostags': 'VBG',
#   'fwords': 'Featuring',
#   'nsentences': '1'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'DT,PRP',
#   'fwords': 'The,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'PP', 'fpostags': 'IN', 'fwords': 'With', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,PRP',
#   'fwords': 'XNAMEX,It',
#   'nsentences': '2'},
#  {'fphrases': 'PP', 'fpostags': 'IN', 'fwords': 'In', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'PP', 'fpostags': 'IN', 'fwords': 'Near', 'nsentences': '1'},
#  {'fphrases': 'PP,NP',
#   'fpostags': 'IN,NNS',
#   'fwords': 'In,Prices',
#   'nsentences': '2'},
#  {'fphrases': 'PP,NP',
#   'fpostags': 'IN,PRP',
#   'fwords': 'Near,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP', 'fpostags': 'EX', 'fwords': 'There', 'nsentences': '1'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'EX,DT',
#   'fwords': 'There,The',
#   'nsentences': '2'},
#  {'fphrases': 'VP,SBAR',
#   'fpostags': 'VBN,IN',
#   'fwords': 'Located,While',
#   'nsentences': '2'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,PRP',
#   'fwords': 'XNAMEX,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'DT,DT',
#   'fwords': 'A,This',
#   'nsentences': '2'},
#  {'fphrases': 'PP', 'fpostags': 'IN', 'fwords': 'With', 'nsentences': '1'},
#  {'fphrases': 'VP', 'fpostags': 'VBN', 'fwords': 'Located', 'nsentences': '1'},
#  {'fphrases': 'ADJP,SQ',
#   'fpostags': 'RB,CC',
#   'fwords': 'Moderately,But',
#   'nsentences': '2'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,PRP',
#   'fwords': 'XNAMEX,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'DT,PRP',
#   'fwords': 'The,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP,ADVP',
#   'fpostags': 'NNP,RB',
#   'fwords': 'XNAMEX,Unfortunately',
#   'nsentences': '2'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,PRP',
#   'fwords': 'XNAMEX,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,PRP',
#   'fwords': 'XNAMEX,It',
#   'nsentences': '2'},
#  {'fphrases': 'PP', 'fpostags': 'IN', 'fwords': 'with', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,PRP',
#   'fwords': 'XNAMEX,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP', 'fpostags': 'DT', 'fwords': 'A', 'nsentences': '1'},
#  {'fphrases': 'VP', 'fpostags': 'VBN', 'fwords': 'Located', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'DT,PRP$',
#   'fwords': 'A,Its',
#   'nsentences': '2'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'DT', 'fwords': 'The', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,PRP$',
#   'fwords': 'XNAMEX,Its',
#   'nsentences': '2'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,PRP',
#   'fwords': 'XNAMEX,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,PRP',
#   'fwords': 'XNAMEX,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP,NP,NP,VP,NP',
#   'fpostags': 'NNP,NNS,PRP,MD,DT',
#   'fwords': 'XNAMEX,Prices,They,Can,No',
#   'nsentences': '5'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,DT',
#   'fwords': 'XNAMEX,The',
#   'nsentences': '2'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,DT',
#   'fwords': 'XNAMEX,The',
#   'nsentences': '2'},
#  {'fphrases': 'NP', 'fpostags': 'EX', 'fwords': 'There', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'JJ', 'fwords': 'Fast', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'DT', 'fwords': 'The', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'EX', 'fwords': 'There', 'nsentences': '1'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,PRP$',
#   'fwords': 'XNAMEX,Its',
#   'nsentences': '2'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'PP', 'fpostags': 'IN', 'fwords': 'For', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'ADJP',
#   'fpostags': 'NNP',
#   'fwords': 'Highly',
#   'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'EX', 'fwords': 'There', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'DT,JJ',
#   'fwords': 'All,Midsummer',
#   'nsentences': '2'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,PRP',
#   'fwords': 'XNAMEX,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,PRP$',
#   'fwords': 'XNAMEX,Its',
#   'nsentences': '2'},
#  {'fphrases': 'NP,NP,NP',
#   'fpostags': 'NNP,PRP,PRP$',
#   'fwords': 'XNAMEX,It,Its',
#   'nsentences': '3'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'PP,NP',
#   'fpostags': 'IN,PRP',
#   'fwords': 'In,It',
#   'nsentences': '2'},
#  {'fphrases': 'PP', 'fpostags': 'IN', 'fwords': 'For', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,PRP',
#   'fwords': 'XNAMEX,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,PRP',
#   'fwords': 'XNAMEX,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,NNS',
#   'fwords': 'XNAMEX,Prices',
#   'nsentences': '2'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,PRP',
#   'fwords': 'XNAMEX,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP', 'fpostags': 'NNS', 'fwords': 'eggs', 'nsentences': '1'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,NNS',
#   'fwords': 'XNAMEX,Customers',
#   'nsentences': '2'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP,LST',
#   'fpostags': 'NNP,LS',
#   'fwords': 'XNAMEX,1',
#   'nsentences': '2'},
#  {'fphrases': 'PP,VP',
#   'fpostags': 'IN,VB',
#   'fwords': 'Near,and',
#   'nsentences': '2'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,PRP$',
#   'fwords': 'XNAMEX,its',
#   'nsentences': '2'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,PRP',
#   'fwords': 'XNAMEX,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP,VP',
#   'fpostags': 'CD,VBN',
#   'fwords': '5,Located',
#   'nsentences': '2'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'DT', 'fwords': 'The', 'nsentences': '1'},
#  {'fphrases': 'NP,NP,NP',
#   'fpostags': 'NNP,PRP,PRP',
#   'fwords': 'XNAMEX,It,It',
#   'nsentences': '3'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,PRP',
#   'fwords': 'XNAMEX,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP,ADJP',
#   'fpostags': 'NNP,RB',
#   'fwords': 'XNAMEX,Close',
#   'nsentences': '2'},
#  {'fphrases': 'NP', 'fpostags': 'DT', 'fwords': 'The', 'nsentences': '1'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'DT,PRP',
#   'fwords': 'The,They',
#   'nsentences': '2'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'EX,PRP',
#   'fwords': 'There,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,PRP$',
#   'fwords': 'XNAMEX,Its',
#   'nsentences': '2'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,PRP',
#   'fwords': 'XNAMEX,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP', 'fpostags': 'DT', 'fwords': 'A', 'nsentences': '1'},
#  {'fphrases': 'NP,NP,NP',
#   'fpostags': 'NNP,PRP,PRP',
#   'fwords': 'XNAMEX,It,It',
#   'nsentences': '3'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,PRP',
#   'fwords': 'XNAMEX,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP,NP,NP',
#   'fpostags': 'NNP,PRP,JJ',
#   'fwords': 'XNAMEX,It,High',
#   'nsentences': '3'},
#  {'fphrases': 'NP', 'fpostags': 'JJ', 'fwords': 'English', 'nsentences': '1'},
#  {'fphrases': 'VP', 'fpostags': 'VBP', 'fwords': 'Do', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,PRP',
#   'fwords': 'XNAMEX,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP,NP,NP',
#   'fpostags': 'NNP,NNS,NNP',
#   'fwords': 'XNAMEX,Customers,XNAMEX',
#   'nsentences': '3'},
#  {'fphrases': 'PP', 'fpostags': 'IN', 'fwords': 'Near', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'DT', 'fwords': 'A', 'nsentences': '1'},
#  {'fphrases': 'PP,NP',
#   'fpostags': 'IN,NNP',
#   'fwords': 'In,Serving',
#   'nsentences': '2'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP,SQ',
#   'fpostags': 'JJ,VBZ',
#   'fwords': 'Italian,Is',
#   'nsentences': '2'},
#  {'fphrases': 'PP', 'fpostags': 'IN', 'fwords': 'In', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'High', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP',
#   'fpostags': 'NNP',
#   'fwords': 'Offering',
#   'nsentences': '1'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,NNP',
#   'fwords': 'XNAMEX,XNAMEX',
#   'nsentences': '2'},
#  {'fphrases': 'NP,NP,NP',
#   'fpostags': 'NNP,PRP,PRP',
#   'fwords': 'XNAMEX,They,They',
#   'nsentences': '3'},
#  {'fphrases': 'PP', 'fpostags': 'IN', 'fwords': 'In', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,PRP',
#   'fwords': 'XNAMEX,It',
#   'nsentences': '2'},
#  {'fphrases': 'VP', 'fpostags': 'VBG', 'fwords': 'Serving', 'nsentences': '1'},
#  {'fphrases': 'VP', 'fpostags': 'VBN', 'fwords': 'Located', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'EX', 'fwords': 'There', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP,NP,NP',
#   'fpostags': 'NNP,PRP,PRP$',
#   'fwords': 'XNAMEX,It,Its',
#   'nsentences': '3'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'DT,PRP',
#   'fwords': 'The,It',
#   'nsentences': '2'},
#  {'fphrases': 'SBAR', 'fpostags': 'IN', 'fwords': 'If', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'DT', 'fwords': 'A', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'DT', 'fwords': 'A', 'nsentences': '1'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,PRP',
#   'fwords': 'XNAMEX,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP', 'fpostags': 'EX', 'fwords': 'There', 'nsentences': '1'},
#  {'fphrases': 'NP,ADVP',
#   'fpostags': 'NNP,RB',
#   'fwords': 'XNAMEX,nearby',
#   'nsentences': '2'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'SBAR', 'fpostags': 'IN', 'fwords': 'If', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'VP', 'fpostags': 'VBN', 'fwords': 'Located', 'nsentences': '1'},
#  {'fphrases': 'NP,VP',
#   'fpostags': 'NNP,VBG',
#   'fwords': 'XNAMEX,Whilst',
#   'nsentences': '2'},
#  {'fphrases': 'VP', 'fpostags': 'VBN', 'fwords': 'Located', 'nsentences': '1'},
#  {'fphrases': 'PP', 'fpostags': 'IN', 'fwords': 'For', 'nsentences': '1'},
#  {'fphrases': 'PP,NP',
#   'fpostags': 'IN,PRP',
#   'fwords': 'For,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'EX,PRP',
#   'fwords': 'There,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,PRP',
#   'fwords': 'XNAMEX,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,PRP',
#   'fwords': 'XNAMEX,They',
#   'nsentences': '2'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,PRP',
#   'fwords': 'XNAMEX,They',
#   'nsentences': '2'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,PRP',
#   'fwords': 'Low,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP,PP,NP,NP',
#   'fpostags': 'PRP,IN,NNS,NNP',
#   'fwords': 'It,In,Noodles,XNAMEX',
#   'nsentences': '4'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,PRP',
#   'fwords': 'XNAMEX,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP', 'fpostags': 'EX', 'fwords': 'There', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'Low', 'nsentences': '1'},
#  {'fphrases': 'WHADVP',
#   'fpostags': 'WRB',
#   'fwords': 'When',
#   'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'High', 'nsentences': '1'},
#  {'fphrases': 'PP', 'fpostags': 'IN', 'fwords': 'For', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'EX', 'fwords': 'There', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'DT', 'fwords': 'A', 'nsentences': '1'},
#  {'fphrases': 'NP,NP,NP',
#   'fpostags': 'NNP,PRP,PRP$',
#   'fwords': 'XNAMEX,It,Its',
#   'nsentences': '3'},
#  {'fphrases': 'SBAR,NP',
#   'fpostags': 'IN,PRP',
#   'fwords': 'If,It',
#   'nsentences': '2'},
#  {'fphrases': 'VP', 'fpostags': 'VBN', 'fwords': 'Located', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,NNP',
#   'fwords': 'Riverside,XNAMEX',
#   'nsentences': '2'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'EX,PRP',
#   'fwords': 'There,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP,SBAR',
#   'fpostags': 'NNP,IN',
#   'fwords': 'XNAMEX,Although',
#   'nsentences': '2'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,PRP',
#   'fwords': 'XNAMEX,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,PRP',
#   'fwords': 'XNAMEX,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP,SBAR',
#   'fpostags': 'NNP,IN',
#   'fwords': 'XNAMEX,Although',
#   'nsentences': '2'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,PRP',
#   'fwords': 'XNAMEX,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,PRP$',
#   'fwords': 'XNAMEX,Their',
#   'nsentences': '2'},
#  {'fphrases': 'VP', 'fpostags': 'VBN', 'fwords': 'Rated', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'CD', 'fwords': '5', 'nsentences': '1'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,PRP',
#   'fwords': 'XNAMEX,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP,NP,NP',
#   'fpostags': 'NNP,PRP,PRP',
#   'fwords': 'XNAMEX,It,It',
#   'nsentences': '3'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,PRP',
#   'fwords': 'XNAMEX,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'EX,PRP',
#   'fwords': 'There,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'PP,FRAG',
#   'fpostags': 'IN,RB',
#   'fwords': 'For,Not',
#   'nsentences': '2'},
#  {'fphrases': 'VP,NP',
#   'fpostags': 'VBN,DT',
#   'fwords': 'Located,This',
#   'nsentences': '2'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,PRP',
#   'fwords': 'XNAMEX,It',
#   'nsentences': '2'},
#  {'fphrases': 'PP', 'fpostags': 'IN', 'fwords': 'Near', 'nsentences': '1'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,PRP',
#   'fwords': 'XNAMEX,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,PRP',
#   'fwords': 'XNAMEX,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,PRP',
#   'fwords': 'XNAMEX,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,NNP',
#   'fwords': 'XNAMEX,Café',
#   'nsentences': '2'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'S', 'fpostags': 'RB', 'fwords': 'Not', 'nsentences': '1'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'DT,PRP',
#   'fwords': 'The,It',
#   'nsentences': '2'},
#  {'fphrases': 'INTJ,NP,NP',
#   'fpostags': 'UH,PRP,PRP',
#   'fwords': 'Welcome,We,We',
#   'nsentences': '3'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'EX,PRP',
#   'fwords': 'There,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,PRP',
#   'fwords': 'XNAMEX,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,DT',
#   'fwords': 'XNAMEX,This',
#   'nsentences': '2'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'DT', 'fwords': 'The', 'nsentences': '1'},
#  {'fphrases': 'VP', 'fpostags': 'VBN', 'fwords': 'Located', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'DT', 'fwords': 'A', 'nsentences': '1'},
#  {'fphrases': 'PP', 'fpostags': 'IN', 'fwords': 'With', 'nsentences': '1'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,PRP',
#   'fwords': 'XNAMEX,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP,NP,NP',
#   'fpostags': 'NNP,PRP,PRP$',
#   'fwords': 'XNAMEX,It,Its',
#   'nsentences': '3'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,PRP',
#   'fwords': 'XNAMEX,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP,VP',
#   'fpostags': 'DT,VBN',
#   'fwords': 'A,Located',
#   'nsentences': '2'},
#  {'fphrases': 'NP', 'fpostags': 'DT', 'fwords': 'A', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'PP', 'fpostags': 'IN', 'fwords': 'In', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'DT', 'fwords': 'The', 'nsentences': '1'},
#  {'fphrases': 'NP,NP,FRAG',
#   'fpostags': 'NNP,NNP,RB',
#   'fwords': 'XNAMEX,Average,Not',
#   'nsentences': '3'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,PRP',
#   'fwords': 'XNAMEX,They',
#   'nsentences': '2'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'DT', 'fwords': 'The', 'nsentences': '1'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,PRP',
#   'fwords': 'XNAMEX,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'EX', 'fwords': 'There', 'nsentences': '1'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'DT,PRP',
#   'fwords': 'An,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP,NP,NP',
#   'fpostags': 'NNP,PRP,PRP$',
#   'fwords': 'XNAMEX,You,its',
#   'nsentences': '3'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,PRP',
#   'fwords': 'XNAMEX,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,PRP',
#   'fwords': 'XNAMEX,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,PRP',
#   'fwords': 'XNAMEX,It',
#   'nsentences': '2'},
#  {'fphrases': 'PP', 'fpostags': 'IN', 'fwords': 'With', 'nsentences': '1'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,PRP',
#   'fwords': 'XNAMEX,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'DT,PRP',
#   'fwords': 'The,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'SBAR,NP,NP',
#   'fpostags': 'IN,PRP,PRP',
#   'fwords': 'If,It,It',
#   'nsentences': '3'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,PRP',
#   'fwords': 'XNAMEX,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'VP', 'fpostags': 'VBN', 'fwords': 'Priced', 'nsentences': '1'},
#  {'fphrases': 'VP', 'fpostags': 'VBN', 'fwords': 'Located', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'PP', 'fpostags': 'IN', 'fwords': 'With', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'EX', 'fwords': 'There', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP,NP,NP,NP',
#   'fpostags': 'NNP,PRP,PRP,DT',
#   'fwords': 'XNAMEX,It,It,The',
#   'nsentences': '4'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'EX,PRP',
#   'fwords': 'There,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'Pub', 'nsentences': '1'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'EX,PRP',
#   'fwords': 'There,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'VP', 'fpostags': 'VBN', 'fwords': 'located', 'nsentences': '1'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,DT',
#   'fwords': 'XNAMEX,The',
#   'nsentences': '2'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'EX,PRP',
#   'fwords': 'There,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,PRP',
#   'fwords': 'XNAMEX,It',
#   'nsentences': '2'},
#  {'fphrases': 'PP', 'fpostags': 'IN', 'fwords': 'Near', 'nsentences': '1'},
#  {'fphrases': 'PP', 'fpostags': 'IN', 'fwords': 'In', 'nsentences': '1'},
#  {'fphrases': 'NP,ADVP',
#   'fpostags': 'NNP,RB',
#   'fwords': 'XNAMEX,Unfortunately',
#   'nsentences': '2'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,PRP',
#   'fwords': 'XNAMEX,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP',
#   'fpostags': 'NNP',
#   'fwords': 'Riverside',
#   'nsentences': '1'},
#  {'fphrases': 'PP', 'fpostags': 'IN', 'fwords': 'In', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'PP', 'fpostags': 'IN', 'fwords': 'Near', 'nsentences': '1'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'EX,PRP',
#   'fwords': 'There,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP', 'fpostags': 'DT', 'fwords': 'A', 'nsentences': '1'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,PRP',
#   'fwords': 'XNAMEX,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'DT,DT',
#   'fwords': 'A,The',
#   'nsentences': '2'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'NN', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'SBAR,NP',
#   'fpostags': 'IN,PRP',
#   'fwords': 'By,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'Kid', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'VP', 'fpostags': 'VBN', 'fwords': 'Located', 'nsentences': '1'},
#  {'fphrases': 'VP',
#   'fpostags': 'VBG',
#   'fwords': 'Providing',
#   'nsentences': '1'},
#  {'fphrases': 'PP', 'fpostags': 'IN', 'fwords': 'For', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'PP', 'fpostags': 'IN', 'fwords': 'Near', 'nsentences': '1'},
#  {'fphrases': 'VP', 'fpostags': 'VBN', 'fwords': 'Located', 'nsentences': '1'},
#  {'fphrases': 'PP', 'fpostags': 'IN', 'fwords': 'In', 'nsentences': '1'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'EX,PRP',
#   'fwords': 'There,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,PRP',
#   'fwords': 'XNAMEX,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,PRP',
#   'fwords': 'XNAMEX,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP', 'fpostags': 'EX', 'fwords': 'There', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'DT', 'fwords': 'The', 'nsentences': '1'},
#  {'fphrases': 'ADVP',
#   'fpostags': 'RB',
#   'fwords': 'Moderately',
#   'nsentences': '1'},
#  {'fphrases': 'PP,NP',
#   'fpostags': 'IN,DT',
#   'fwords': 'In,An',
#   'nsentences': '2'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,PRP',
#   'fwords': 'XNAMEX,it',
#   'nsentences': '2'},
#  {'fphrases': 'VP', 'fpostags': 'VBN', 'fwords': 'Located', 'nsentences': '1'},
#  {'fphrases': 'NP,NP,NP,NP',
#   'fpostags': 'NNP,PRP,PRP,PRP$',
#   'fwords': 'XNAMEX,It,It,Its',
#   'nsentences': '4'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'DT,PRP',
#   'fwords': 'The,They',
#   'nsentences': '2'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,PRP',
#   'fwords': 'XNAMEX,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,PRP',
#   'fwords': 'XNAMEX,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'PRP,PRP',
#   'fwords': 'You,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'PP,NP',
#   'fpostags': 'IN,PRP',
#   'fwords': 'Near,They',
#   'nsentences': '2'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,PRP',
#   'fwords': 'XNAMEX,They',
#   'nsentences': '2'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,PRP',
#   'fwords': 'XNAMEX,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,PRP',
#   'fwords': 'XNAMEX,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP', 'fpostags': 'DT', 'fwords': 'A', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP',
#   'fpostags': 'NNP',
#   'fwords': 'Children',
#   'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,NNP',
#   'fwords': 'XNAMEX,Price',
#   'nsentences': '2'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP,SBAR',
#   'fpostags': 'EX,IN',
#   'fwords': 'There,Although',
#   'nsentences': '2'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'DT', 'fwords': 'The', 'nsentences': '1'},
#  {'fphrases': 'VP', 'fpostags': 'VBN', 'fwords': 'Located', 'nsentences': '1'},
#  {'fphrases': 'VP', 'fpostags': 'VBN', 'fwords': 'Located', 'nsentences': '1'},
#  {'fphrases': 'VP', 'fpostags': 'VB', 'fwords': 'Want', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'EX', 'fwords': 'There', 'nsentences': '1'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,PRP',
#   'fwords': 'XNAMEX,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP', 'fpostags': 'EX', 'fwords': 'There', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'DT', 'fwords': 'A', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'EX', 'fwords': 'There', 'nsentences': '1'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'EX,PRP',
#   'fwords': 'There,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP', 'fpostags': 'DT', 'fwords': 'The', 'nsentences': '1'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,PRP',
#   'fwords': 'XNAMEX,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,PRP$',
#   'fwords': 'XNAMEX,Its',
#   'nsentences': '2'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,PRP$',
#   'fwords': 'XNAMEX,Its',
#   'nsentences': '2'},
#  {'fphrases': 'NP', 'fpostags': 'EX', 'fwords': 'There', 'nsentences': '1'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,PRP',
#   'fwords': 'XNAMEX,It',
#   'nsentences': '2'},
#  {'fphrases': 'VP,NP',
#   'fpostags': 'VB,JJ',
#   'fwords': 'Eat,French',
#   'nsentences': '2'},
#  {'fphrases': 'NP', 'fpostags': 'DT', 'fwords': 'A', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'EX', 'fwords': 'there', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'VP', 'fpostags': 'VBN', 'fwords': 'Located', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'VP,NP',
#   'fpostags': 'VBN,IN',
#   'fwords': 'Located,On',
#   'nsentences': '2'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'EX', 'fwords': 'There', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'DT', 'fwords': 'A', 'nsentences': '1'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'DT,PRP',
#   'fwords': 'The,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'JJ,DT',
#   'fwords': 'Italian,This',
#   'nsentences': '2'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'SBAR,NP,NP',
#   'fpostags': 'IN,PRP,PRP',
#   'fwords': 'Although,It,It',
#   'nsentences': '3'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,PRP',
#   'fwords': 'XNAMEX,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP,NP,NP',
#   'fpostags': 'EX,PRP,DT',
#   'fwords': 'There,It,The',
#   'nsentences': '3'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,PRP',
#   'fwords': 'XNAMEX,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP',
#   'fpostags': 'NNS',
#   'fwords': 'Customers',
#   'nsentences': '1'},
#  {'fphrases': 'NP,NP,NP',
#   'fpostags': 'NNP,PRP$,PRP',
#   'fwords': 'XNAMEX,Their,They',
#   'nsentences': '3'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'VP', 'fpostags': 'VBG', 'fwords': 'Scoring', 'nsentences': '1'},
#  {'fphrases': 'NP,SBAR',
#   'fpostags': 'NNP,IN',
#   'fwords': 'XNAMEX,While',
#   'nsentences': '2'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'PP', 'fpostags': 'IN', 'fwords': 'In', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'SBAR,NP',
#   'fpostags': 'IN,PRP',
#   'fwords': 'If,I',
#   'nsentences': '2'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,PRP',
#   'fwords': 'XNAMEX,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'DT', 'fwords': 'The', 'nsentences': '1'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,PRP',
#   'fwords': 'XNAMEX,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'EX,PRP',
#   'fwords': 'There,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,PRP',
#   'fwords': 'XNAMEX,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'DT,PRP',
#   'fwords': 'The,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP', 'fpostags': 'JJ', 'fwords': 'Average', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'DT', 'fwords': 'A', 'nsentences': '1'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,PRP',
#   'fwords': 'XNAMEX,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'EX', 'fwords': 'There', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'PP', 'fpostags': 'IN', 'fwords': 'Near', 'nsentences': '1'},
#  {'fphrases': 'NP,NP,NP,NP,NP,NP',
#   'fpostags': 'NNP,PRP,PRP,PRP,PRP,PRP',
#   'fwords': 'XNAMEX,It,It,It,It,It',
#   'nsentences': '6'},
#  {'fphrases': 'NP', 'fpostags': 'DT', 'fwords': 'An', 'nsentences': '1'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,DT',
#   'fwords': 'XNAMEX,This',
#   'nsentences': '2'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'NN', 'fwords': 'price', 'nsentences': '1'},
#  {'fphrases': 'VP', 'fpostags': 'VB', 'fwords': 'Find', 'nsentences': '1'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'EX,PRP',
#   'fwords': 'There,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP', 'fpostags': 'DT', 'fwords': 'The', 'nsentences': '1'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'DT,PRP',
#   'fwords': 'The,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,DT',
#   'fwords': 'XNAMEX,The',
#   'nsentences': '2'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'PRP', 'fwords': 'You', 'nsentences': '1'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,NNP',
#   'fwords': 'XNAMEX,XNAMEX',
#   'nsentences': '2'},
#  {'fphrases': 'NP', 'fpostags': 'EX', 'fwords': 'There', 'nsentences': '1'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,PRP',
#   'fwords': 'XNAMEX,It',
#   'nsentences': '2'},
#  {'fphrases': 'VP', 'fpostags': 'VB', 'fwords': 'Check', 'nsentences': '1'},
#  {'fphrases': 'NP,NP',
# ...
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'PP', 'fpostags': 'IN', 'fwords': 'Near', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP,VP',
#   'fpostags': 'DT,VBN',
#   'fwords': 'A,Located',
#   'nsentences': '2'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'DT,PRP',
#   'fwords': 'The,It',
#   'nsentences': '2'},
#  {'fphrases': 'PP', 'fpostags': 'IN', 'fwords': 'For', 'nsentences': '1'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,PRP',
#   'fwords': 'XNAMEX,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,PRP',
#   'fwords': 'XNAMEX,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,PRP',
#   'fwords': 'XNAMEX,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,DT',
#   'fwords': 'XNAMEX,The',
#   'nsentences': '2'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,PRP',
#   'fwords': 'XNAMEX,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'PP', 'fpostags': 'IN', 'fwords': 'In', 'nsentences': '1'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,DT',
#   'fwords': 'XNAMEX,This',
#   'nsentences': '2'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'DT,PRP',
#   'fwords': 'A,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,PRP',
#   'fwords': 'XNAMEX,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,DT',
#   'fwords': 'XNAMEX,The',
#   'nsentences': '2'},
#  {'fphrases': 'NP',
#   'fpostags': 'NNP',
#   'fwords': 'Riverside',
#   'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'JJ', 'fwords': 'Fast', 'nsentences': '1'},
#  {'fphrases': 'NP,NP,NP',
#   'fpostags': 'NNP,PRP,PRP',
#   'fwords': 'XNAMEX,It,It',
#   'nsentences': '3'},
#  {'fphrases': 'PP', 'fpostags': 'IN', 'fwords': 'For', 'nsentences': '1'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,PRP',
#   'fwords': 'XNAMEX,They',
#   'nsentences': '2'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'PP,NP',
#   'fpostags': 'IN,NN',
#   'fwords': 'In,Customer',
#   'nsentences': '2'},
#  {'fphrases': 'NP', 'fpostags': 'EX', 'fwords': 'There', 'nsentences': '1'},
#  {'fphrases': 'PP', 'fpostags': 'IN', 'fwords': 'At', 'nsentences': '1'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,PRP',
#   'fwords': 'XNAMEX,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'EX,PRP',
#   'fwords': 'There,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,NNS',
#   'fwords': 'XNAMEX,Prices',
#   'nsentences': '2'},
#  {'fphrases': 'NP', 'fpostags': 'EX', 'fwords': 'There', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'EX,PRP',
#   'fwords': 'There,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'DT,PRP',
#   'fwords': 'The,It',
#   'nsentences': '2'},
#  {'fphrases': 'PP,VP',
#   'fpostags': 'IN,VB',
#   'fwords': 'Near,Child',
#   'nsentences': '2'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'EX,PRP',
#   'fwords': 'There,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'DT,PRP',
#   'fwords': 'A,It',
#   'nsentences': '2'},
#  {'fphrases': 'PP', 'fpostags': 'IN', 'fwords': 'Off', 'nsentences': '1'},
#  {'fphrases': 'NP,VP',
#   'fpostags': 'NNP,VBN',
#   'fwords': 'XNAMEX,Located',
#   'nsentences': '2'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'DT', 'fwords': 'A', 'nsentences': '1'},
#  {'fphrases': 'PP', 'fpostags': 'IN', 'fwords': 'At', 'nsentences': '1'},
#  {'fphrases': 'NP,INTJ',
#   'fpostags': 'NNP,UH',
#   'fwords': 'XNAMEX,Yes',
#   'nsentences': '2'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'DT', 'fwords': 'The', 'nsentences': '1'},
#  {'fphrases': 'NP,NP,NP',
#   'fpostags': 'NNP,PRP,PRP',
#   'fwords': 'XNAMEX,It,I',
#   'nsentences': '3'},
#  {'fphrases': 'VP,NP',
#   'fpostags': 'VB,PRP',
#   'fwords': 'Found,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP,NP,NP',
#   'fpostags': 'NNP,PRP,PRP',
#   'fwords': 'XNAMEX,It,It',
#   'nsentences': '3'},
#  {'fphrases': 'PP,NP',
#   'fpostags': 'IN,DT',
#   'fwords': 'Near,This',
#   'nsentences': '2'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'EX,PRP',
#   'fwords': 'There,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP,NP,NP',
#   'fpostags': 'NNP,PRP,PRP',
#   'fwords': 'XNAMEX,It,It',
#   'nsentences': '3'},
#  {'fphrases': 'PP', 'fpostags': 'IN', 'fwords': 'For', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNS,DT',
#   'fwords': 'Customers,This',
#   'nsentences': '2'},
#  {'fphrases': 'PP,NP',
#   'fpostags': 'IN,PRP',
#   'fwords': 'In,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,PRP',
#   'fwords': 'XNAMEX,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP,PP',
#   'fpostags': 'NNP,IN',
#   'fwords': 'XNAMEX,For',
#   'nsentences': '2'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'DT,PRP',
#   'fwords': 'A,It',
#   'nsentences': '2'},
#  {'fphrases': 'PP', 'fpostags': 'IN', 'fwords': 'Along', 'nsentences': '1'},
#  {'fphrases': 'PP', 'fpostags': 'IN', 'fwords': 'With', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'EX', 'fwords': 'There', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'DT', 'fwords': 'The', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'EX', 'fwords': 'There', 'nsentences': '1'},
#  {'fphrases': 'VP', 'fpostags': 'VB', 'fwords': 'Come', 'nsentences': '1'},
#  {'fphrases': 'PP', 'fpostags': 'IN', 'fwords': 'Near', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'DT', 'fwords': 'The', 'nsentences': '1'},
#  {'fphrases': 'NP,NP,NP',
#   'fpostags': 'NNP,JJ,NN',
#   'fwords': 'Near,Chinese,Customer',
#   'nsentences': '3'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'SBAR,NP',
#   'fpostags': 'IN,PRP',
#   'fwords': 'If,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,PRP',
#   'fwords': 'XNAMEX,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,PRP',
#   'fwords': 'XNAMEX,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'DT,PRP',
#   'fwords': 'The,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP', 'fpostags': 'DT', 'fwords': 'A', 'nsentences': '1'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,PRP',
#   'fwords': 'XNAMEX,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NN,PRP',
#   'fwords': 'XNAMEX,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP', 'fpostags': 'JJ', 'fwords': 'Japanese', 'nsentences': '1'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,PRP',
#   'fwords': 'XNAMEX,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'PP', 'fpostags': 'IN', 'fwords': 'Near', 'nsentences': '1'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,PRP',
#   'fwords': 'XNAMEX,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,PRP',
#   'fwords': 'XNAMEX,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,PRP',
#   'fwords': 'XNAMEX,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP', 'fpostags': 'EX', 'fwords': 'There', 'nsentences': '1'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,PRP',
#   'fwords': 'XNAMEX,It',
#   'nsentences': '2'},
#  {'fphrases': 'PP', 'fpostags': 'IN', 'fwords': 'Near', 'nsentences': '1'},
#  {'fphrases': 'NP,NP,NP',
#   'fpostags': 'NNP,PRP,PRP',
#   'fwords': 'XNAMEX,It,It',
#   'nsentences': '3'},
#  {'fphrases': 'S,NP,NP',
#   'fpostags': '``,PRP,DT',
#   'fwords': '`,It,The',
#   'nsentences': '3'},
#  {'fphrases': 'NP', 'fpostags': 'DT', 'fwords': 'A', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'PP,NP',
#   'fpostags': 'IN,PRP',
#   'fwords': 'By,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,PRP',
#   'fwords': 'XNAMEX,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP,NP,NP',
#   'fpostags': 'NNP,PRP,DT',
#   'fwords': 'XNAMEX,It,The',
#   'nsentences': '3'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'PP,NP',
#   'fpostags': 'IN,PRP',
#   'fwords': 'On,They',
#   'nsentences': '2'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'VP', 'fpostags': 'VBN', 'fwords': 'Located', 'nsentences': '1'},
#  {'fphrases': 'PP,PP',
#   'fpostags': 'IN,IN',
#   'fwords': 'Near,On',
#   'nsentences': '2'},
#  {'fphrases': 'NP', 'fpostags': 'DT', 'fwords': 'The', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,DT',
#   'fwords': 'XNAMEX,The',
#   'nsentences': '2'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'DT', 'fwords': 'The', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'EX', 'fwords': 'There', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,PRP',
#   'fwords': 'XNAMEX,It',
#   'nsentences': '2'},
#  {'fphrases': 'PP', 'fpostags': 'IN', 'fwords': 'Near', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'DT', 'fwords': 'The', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'EX', 'fwords': 'There', 'nsentences': '1'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,PRP',
#   'fwords': 'XNAMEX,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,PRP',
#   'fwords': 'XNAMEX,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP,PP,NP',
#   'fpostags': 'DT,IN,PRP',
#   'fwords': 'A,In,It',
#   'nsentences': '3'},
#  {'fphrases': 'NP,NP,NP',
#   'fpostags': 'NNP,PRP$,PRP',
#   'fwords': 'XNAMEX,Its,It',
#   'nsentences': '3'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,PRP',
#   'fwords': 'XNAMEX,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'DT,PRP',
#   'fwords': 'The,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP',
#   'fpostags': 'NNP',
#   'fwords': 'Riverside',
#   'nsentences': '1'},
#  {'fphrases': 'PP', 'fpostags': 'IN', 'fwords': 'For', 'nsentences': '1'},
#  {'fphrases': 'NP,VP',
#   'fpostags': 'JJ,VBN',
#   'fwords': 'French,Located',
#   'nsentences': '2'},
#  {'fphrases': 'VP', 'fpostags': 'VBN', 'fwords': 'Rated', 'nsentences': '1'},
#  {'fphrases': 'NP,NP,NP',
#   'fpostags': 'EX,PRP,PRP$',
#   'fwords': 'There,They,Its',
#   'nsentences': '3'},
#  {'fphrases': 'PP,NP',
#   'fpostags': 'IN,PRP',
#   'fwords': 'In,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'PP', 'fpostags': 'IN', 'fwords': 'Near', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'VP', 'fpostags': 'VBN', 'fwords': 'Located', 'nsentences': '1'},
#  {'fphrases': 'NP,NP,NP,NP',
#   'fpostags': 'NNP,PRP,PRP,PRP',
#   'fwords': 'XNAMEX,It,It,It',
#   'nsentences': '4'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,PRP',
#   'fwords': 'XNAMEX,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,PRP',
#   'fwords': 'XNAMEX,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,PRP',
#   'fwords': 'XNAMEX,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,PRP',
#   'fwords': 'XNAMEX,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP,PP',
#   'fpostags': 'NNP,IN',
#   'fwords': 'XNAMEX,For',
#   'nsentences': '2'},
#  {'fphrases': 'NP,NP,NP,VP',
#   'fpostags': 'NNP,PRP,PRP,VB',
#   'fwords': 'XNAMEX,We,We,Join',
#   'nsentences': '4'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'VP,NP',
#   'fpostags': 'VBN,NNP',
#   'fwords': 'Rated,XNAMEX',
#   'nsentences': '2'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,PRP',
#   'fwords': 'XNAMEX,It',
#   'nsentences': '2'},
#  {'fphrases': 'PP', 'fpostags': 'IN', 'fwords': 'In', 'nsentences': '1'},
#  {'fphrases': 'ADVP', 'fpostags': 'RB', 'fwords': 'Yes', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP,ADVP',
#   'fpostags': 'NNP,RB',
#   'fwords': 'XNAMEX,However',
#   'nsentences': '2'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,PRP',
#   'fwords': 'XNAMEX,it',
#   'nsentences': '2'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,PRP',
#   'fwords': 'XNAMEX,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'SBAR', 'fpostags': 'IN', 'fwords': 'If', 'nsentences': '1'},
#  {'fphrases': 'NP,NP,INTJ,NP',
#   'fpostags': 'NNP,PRP,UH,PRP',
#   'fwords': 'XNAMEX,They,.,They',
#   'nsentences': '4'},
#  {'fphrases': 'NP', 'fpostags': 'DT', 'fwords': 'A', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'DT', 'fwords': 'The', 'nsentences': '1'},
#  {'fphrases': 'NP,NP,NP',
#   'fpostags': 'NNP,DT,NNP',
#   'fwords': 'XNAMEX,This,XNAMEX',
#   'nsentences': '3'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,PRP',
#   'fwords': 'XNAMEX,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP', 'fpostags': 'DT', 'fwords': 'The', 'nsentences': '1'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,PRP',
#   'fwords': 'XNAMEX,It',
#   'nsentences': '2'},
#  {'fphrases': 'NP', 'fpostags': 'NNP', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP', 'fpostags': 'NN', 'fwords': 'XNAMEX', 'nsentences': '1'},
#  {'fphrases': 'NP,NP',
#   'fpostags': 'NNP,PRP',
#   'fwords': 'XNAMEX,It',
#   'nsentences': '2'},
#  {'fphrases': 'VP',
#   'fpostags': 'VBG',
#   'fwords': 'Offering',
#   'nsentences': '1'},
#  {'fphrases': 'NP,PP',
#   'fpostags': 'NNP,IN',
#   'fwords': 'XNAMEX,With',
#   'nsentences': '2'},
#  ...]

# %%
#max sentence length
import operator
sentence_lengths = [x['nsentences'] for x in lex_feature_list]
idx, value = max(enumerate(sentence_lengths), key=operator.itemgetter(1))
features = feature_list[idx]
sentence = sentences[idx]

print(idx, value, features, sentence)
# Out:
# 1214 7 {'name': 'Aromi', 'eatType': 'coffee shop', 'food': 'French', 'customer rating': 'high', 'area': 'riverside', 'familyFriendly': 'yes'} Aromi, stunning coffee shop thats kid friendly.. Yes,  high customer rating.. Yes,  beautiful view.. Riverside and the very best French food .

# %%
from collections import Counter
c = Counter(sentence_lengths)
c
# Out:
# Counter({'1': 23738,
#          '2': 15126,
#          '3': 2652,
#          '4': 461,
#          '5': 72,
#          '6': 11,
#          '7': 1})

# %%
indices_5 = [i for i, x in enumerate(sentence_lengths) if x == '3']
print(len(indices_5))
for idx in indices_5[:50]:
    print(sentences[idx])
    print()
# Out:
# 2652
# The Golden Curry offers English food at a high price. It is near The Bakers. It should be noted that it is not kids friendly.
#
# Green Man is a French restaurant in the city centre. It is not child friendly and is located near All Bar One. It costs more than thirty pounds.
#
# Blue Spice is a coffee shop along the river near Avalon. The prices are quite high while the customer ratings are quite low. It is not recommended to take children there.
#
# A good coffee shop that received a customer rating of 5 out of 5 is The Eagle. It is in the riverside area near the Burger King. It costs more than 30 pounds and is kid friendly.
#
# Alimentum is Fast food. They are children friendly. The price range is cheap and located near riverside.
#
# Strada offers British food in the low price range. It is family friendly with a 3 out of 5 star rating. You can find it near the Rainbow Vegetarian Café.
#
# The Rice Boat is an average rated place. It is located in the city centre. It provides French food and it isn't family-friendly.
#
# Strada provides Chinese food in the cheap price range. It is near Rainbow Vegetarian Café. Its customer rating is average.
#
# The Vaults is near Café Brazil in the riverside area. It is an expensive coffee shop with an average price range of more than  £30. It has a high customer rating.
#
# The Rice Boat is a cheap family friendly place serving French Food. It is in the riverside area near the Express by Holiday Inn. It has a low customer rating.
#
# The Golden Palace is a coffee Shop. It is located in riverside area. High price range and have 3 out of 5 costumer rating.
#
# Alimentum serves Indian cuisine at cheap, affordable prices. Customers have rated the food as average. Alimentum can be found near the riverside and Yippee Noodle Bar.
#
# The Punter is a family friendly coffee shop in the less than £20 range.  They serve Japanese food and can be found near Café Sicilia.   They have a low customer rating.
#
# The Waterman provides Chinese food in the cheap price range. It is located in the riverside. Its customer rating is 5 out of 5.
#
# Wildwood is a coffee shop providing Indian food in the moderate price range. It is near Ranch. Its customer rating is 3 out of 5.
#
# The Rice Boat provides French food. It is located at riverside near Express by Holiday Inn. It has a price range of more than £30, a low customer rating, and is not children friendly.
#
# Welcome to The Waterman, located by the riverside. We serve English food and our price range is cheap. We are not family-friendly and our customer rating is average.
#
# Strada provides Chinese food in the high price range. It is near Rainbow Vegetarian Café. Its customer rating is 1 out of 5.
#
# The Wrestlers is a place that serves French food less than £20. Average Ratings. Not family-friendly.
#
# The Mill is a coffee shop in the city centre that serves Italian food. You will find it near The Sorrento. its prices are moderate.
#
# If you are in the mood for Japanese food, try The Punter.  It is a family Friendly coffee shop in the less than £20 price range with a low customer Rating.  It is located near Café Sicilia.
#
# Although not family friendly, The Golden Curry has an outstanding rating of 5 out of 5. It serves up some delicious Indian food. It is located in the city centre near Café Rouge.
#
# There is a cheap pub that serves Chinese food called The Olive Grove. It is very cheap. The pub is located by the riverside and is very family friendly.
#
# The Olive Grove is a pub that is kid friendly. Their prices are moderate for their English food. They are located in city centre.
#
# Green Man provides Indian food in the high price range. It is located in the city centre. It is near All Bar One.
#
# The Golden Curry is a restaurant located near The Bakers. It is a kid friendly restaurant that offers a variety of quality native foods. They offer low priced foods for great quality.
#
# Cotto is regularly priced coffee shop serving French food.  It is rated 3 out of 5. It is located near The Portland Arms  neat the city centre.
#
# Wildwood is a pub with a 5 star rating. It serves food and is in the average price range. It is in the city centre.
#
# You can get English cuisine at The Phoenix. It's rated about average. It's also located at the city center.
#
# The Olive Grove is in the centre of the city.  It's a pub that serves English food. It has a price range of less than £20 and is family-friendly.
#
# Blue Spice is located by riverside. It is a family-Friendly place with a customer rating of low. price range is less than £20.
#
# The Wrestlers coffee shop serves French for less than £20. Near Raja Indian Cuisine in riverside. No families.
#
# For a family friendly restaurant try The Golden Curry. It serves French food. The only thing is that it has low customer reviews.
#
# The Japanese restaurant The Rice Boat is not kid friendly, but it is highly rated.  It is near the Express by Holiday Inn in the riverside area.  It  has average prices between £20-25.
#
# There is a 1 star, cheaply priced coffee shop named Fitzbillies. It is located near the river to the North of the city centre. Fitzbillies is not suitable for families.
#
# The Rice Boat is a restaurant providing take-away deliveries in the low price range. It is located in the city centre. Near Express by Holiday Inn.
#
# The Golden Curry is a French restaurant near to The Bakers. Prices are below average for the city. It is not family-friendly.
#
# A coffee shop that serves Japanese food is Cotto. It has cheap prices but a low customer rating. It is located in the center of the city near The Portland Arms.
#
# Cocum is a coffee shop which serves Indian food. It has a high price range and is child friendly. Customers rate this coffee shop 1 out of 5.
#
# Wildwood is a pub providing family-style dining in the medium price range. It is located in the city center. It has a really good reviews.
#
# Browns Cambridge is a coffee shop that serves Indian food. Located in city centre near the Crowne Plaza Hotel, this eatery gets a high rating from its customers of 5 out of 5 stars. Please remember this restaurant is not family friendly.
#
# Zizzi is a cheap pub serving fast food. It is family friendly and has a low customer rating. It is located in the city centre.
#
# The Punter is a coffee shop, which offers Indian food, within a cheap price range. It has a 5 out of 5 customer rating, but it is not family friendly. I t is located near Café Sicilia.
#
# Cotto is a coffee shop on the riverside. It is a more expensive venue providing Italian food near to The Portland Arms. It has a high customer rating
#
# The Twenty Two is in the riverside area. It is located near The Rice Boat. It provides children friendly activities.
#
# Near Café Rouge, in Riverside. Chinese food, The Golden Curry. Customer rating 3 out of 5.
#
# The Rice Boat, an English restaurant, is an affordable family friendly place to eat. It is located in the riverside area, near the Express by Holiday Inn. It has a high customer rating of 5 out of 5.
#
# 'Strada' is a pub near Yippee Noodle Bar. It has an average customer rating and serves Italian food. The prices are moderate.
#
# Midsummer House is near All Bar One. It is an English restaurant. The price range is moderate and customer rating is 1 out of 5.
#
# A children friendly restaurant named The Wrestlers that serves French food. In the city centre area is a coffee shop with a price range of more than 30. It is near Raja Indian Cuisine.

# %%
import _pickle as cPickle
phrase_labels =  [x['fphrases'].split(',') for x in lex_feature_list]
phrase_labels_flat = [x for slist in phrase_labels for x in slist]
c = Counter(phrase_labels_flat)
vocab_keys = set([x for x in phrase_labels_flat if c[x] > 50])
vocab = {}
for i, key in enumerate(vocab_keys):
    vocab[key] = i
ofile = open('vocab_phrase_tags.pkl', 'wb')
cPickle.dump(vocab, ofile)
ofile.close()

# %%
WHADVP_idx = [i for i, x in enumerate(phrase_labels) if x[0] == 'PRN']
for idx in WHADVP_idx[:50]:
    print(sentences[idx])
    print()

# %%
pos_tags = [x['fpostags'].split(',') for x in lex_feature_list]
pos_tags_flat = [x for slist in pos_tags for x in slist]
most_freq_tags = [(tag, freq) for tag, freq in Counter(pos_tags_flat).items() if freq > 100]
vocab = {tag: idx for idx, (tag, freq) in enumerate(most_freq_tags)}
for i, key in enumerate(vocab_keys):
    vocab[key] = i
ofile = open('vocab_pos_tags.pkl', 'wb')
cPickle.dump(vocab, ofile)
ofile.close()

# %%
first_words = [x['fwords'].split(',') for x in lex_feature_list]
first_words_flat = [x for slist in first_words for x in slist]
most_freq_fwords = {tag: freq for tag, freq in Counter(first_words_flat).items() if freq > 120}
vocab_fwords = {}
vocab_fwords = {tag: idx for idx, (tag, freq) in enumerate(most_freq_fwords.items())}
for i, key in enumerate(vocab_fwords.keys()):
    vocab_fwords[key] = i
ofile = open('vocab_fwords.pkl', 'wb')
cPickle.dump(vocab_fwords, ofile)
ofile.close()
sorted_items = ['{}\t{}'.format(x[0], x[1]) for x in sorted(most_freq_fwords.items(), key= lambda x: x[1], reverse=True)]
for s in sorted_items:
    print(s)
# Out:
# XNAMEX	25771
# It	12646
# The	3826
# There	3106
# A	1685
# Located	1637
# They	1406
# Near	1290
# In	1177
# Its	883
# For	713
# This	627
# With	626
# If	475
# Customers	322
# An	262
# You	256
# Customer	224
# Prices	211
# it	195
# Not	188
# Rated	162
# At	151
# Their	150
# We	133
# Children	132
# Although	121

# %%
from collections import defaultdict
first_words = [x['fwords'].split(',') for x in lex_feature_list]
fwords_for_nsent = defaultdict(lambda: [])
for first_word in first_words:
    for i, fword in enumerate(first_word):
        idx = 0 if i == 0 else 1
        fwords_for_nsent[idx].append(fword)
fwords_for_nsent = {k: {vk: vv/len(v) for vk, vv in Counter(v).items() if vv > {0: 60, 1: 100}[k]} for k, v in fwords_for_nsent.items()}
fwords_for_nsent = {k: set(v.keys()) for k, v in fwords_for_nsent.items() if k not in foods}
fwords_for_nsent0 = {x[0].upper() + x[1:]: i for i, x in enumerate(fwords_for_nsent[0]) if x not in foods}
fwords_for_nsent1 = {x[0].upper() + x[1:]: i for i, x in enumerate(fwords_for_nsent[1]) if x not in foods}

fwords_for_nsent0 = {x[0].upper() + x[1:]: i for i, x in enumerate(fwords_for_nsent0)}
fwords_for_nsent1 = {x[0].upper() + x[1:]: i for i, x in enumerate(fwords_for_nsent1)}

ofile = open('vocab_fwords_0.pkl', 'wb')
cPickle.dump(fwords_for_nsent0, ofile)
ofile.close()
ofile = open('vocab_fwords_1.pkl', 'wb')
cPickle.dump(fwords_for_nsent1, ofile)
ofile.close()
fwords_for_nsent0
# Out:
# {'A': 12,
#  'An': 18,
#  'At': 24,
#  'By': 10,
#  'Cheap': 21,
#  'Close': 16,
#  'Come': 19,
#  'Family': 17,
#  'Fast': 9,
#  'For': 5,
#  'Highly': 0,
#  'If': 7,
#  'In': 8,
#  'Located': 22,
#  'Near': 23,
#  'On': 15,
#  'Rated': 11,
#  'Riverside': 4,
#  'Serving': 3,
#  'The': 1,
#  'There': 13,
#  'This': 20,
#  'With': 14,
#  'XNAMEX': 2,
#  'You': 6}

# %%
# Out:
# [('Prices', 1),
#  ('Customer', 2),
#  ('XNAMEX', 3),
#  ('We', 4),
#  ('Customers', 5),
#  ('They', 6),
#  ('With', 7),
#  ('Located', 8),
#  ('This', 9),
#  ('Its', 10),
#  ('The', 11),
#  ('Not', 12),
#  ('You', 13),
#  ('It', 14),
#  ('Their', 15)]

# %%
import json
train_tree_feature_file = open('train_lex_features_tree.json', 'rt', encoding='utf-8')
train_tree_features = json.load(train_tree_feature_file)
dev_tree_feature_file = open('dev_lex_features_tree.json', 'rt', encoding='utf-8')
dev_tree_features = json.load(dev_tree_feature_file)
phrase_level_tags = ['ADJP','ADVP','CONJP','FRAG','INTJ','LST','NAC','NP','NP-TMP','NX','PP','PRN','PRT','QP','RRC','UCP','VP','WHADJP','WHADVP','WHNP','WHPP','X',]
clause_level_tags = ['S','SBAR','SBARQ','SINV','SQ']
word_level_tags = ['CC','CD','DT','EX','FW','IN','JJ','JJR','JJS','LS','MD','NN','NNP','NNPS','NNS','PDT','POS','PRP','PRP$','RB','RBR', 'RBS','RP','SYM','TO','UH','VB','VBD','VBG','VBN','VBP', 'VBZ','WDT','WP','WP$','WRB']

# %%
total_tag_stats = Counter()
for train_tree_feature in train_tree_features:
    for sentence_feature in train_tree_feature:
        total_tag_stats.update(sentence_feature)
        
#min_threshold = 1000
#total_tag_stats = {x : total_tag_stats[x] for x in total_tag_stats if total_tag_stats[x] >= min_threshold }
prase_freq = {p: freq for p, freq in total_tag_stats.items() if p in phrase_level_tags}
pos_freq = {p: freq for p, freq in total_tag_stats.items() if p in word_level_tags}

prase_freq = sorted(prase_freq.items(), key= lambda x: x[1], reverse=True)[int(len(phrase_level_tags) * .20) : int(len(phrase_level_tags) * .70)]
pos_freq = sorted(pos_freq.items(), key=lambda x: x[1], reverse=True)[int(len(word_level_tags) * .20) : int(len(word_level_tags) * .70)]
print(prase_freq)
print(pos_freq)

phrase_vocab = {p[0]: i for i, p in enumerate(prase_freq)}
pos_vocab = {p[0]: i for i, p in enumerate(pos_freq)}

print(phrase_vocab)
print(pos_vocab)

json.dump(phrase_vocab, open('phrase_vocab.json', 'wt', encoding='utf-8'))
json.dump(pos_vocab, open('pos_vocab.json', 'wt', encoding='utf-8'))
# Out:
# [('WHNP', 8164), ('ADVP', 7011), ('QP', 5816), ('PRT', 685), ('UCP', 561), ('FRAG', 470), ('WHADVP', 295), ('NX', 252), ('PRN', 233), ('INTJ', 229), ('NP-TMP', 166)]
# [('VBN', 28290), ('RB', 24804), ('PRP', 20784), ('CC', 19628), ('NNS', 16608), ('WDT', 8070), ('VBP', 6464), ('VBG', 5460), ('JJR', 5099), ('VB', 4497), ('EX', 4159), ('TO', 3613), ('VBD', 2951), ('PRP$', 2487), ('MD', 1802), ('NNPS', 1539), ('RP', 691), ('POS', 324)]
# {'WHNP': 0, 'ADVP': 1, 'QP': 2, 'PRT': 3, 'UCP': 4, 'FRAG': 5, 'WHADVP': 6, 'NX': 7, 'PRN': 8, 'INTJ': 9, 'NP-TMP': 10}
# {'VBN': 0, 'RB': 1, 'PRP': 2, 'CC': 3, 'NNS': 4, 'WDT': 5, 'VBP': 6, 'VBG': 7, 'JJR': 8, 'VB': 9, 'EX': 10, 'TO': 11, 'VBD': 12, 'PRP$': 13, 'MD': 14, 'NNPS': 15, 'RP': 16, 'POS': 17}

# %%
lens = {
    'nsent',
    'fout_word_vectors',
    'fout_phrase_vectors',
    'fout_pos_vectors',
    'fword_vectors',
    'fphrase_vectors',
    'fpos_vectors',
    'pos_tag_feature',
    'phrase_tag_feature',
}
lens.keys()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-57-dac92e06e176> in <module>()
#       1 lens = {
# ----> 2     'nsent': max_sentences,
#       3     'fout_word_vectors': dummy_fword_idx0 + 2,
#       4     'fout_phrase_vectors': dummy_fphrtag_idx + 2,
#       5     'fout_pos_vectors': dummy_fpostag_idx + 2,
#
# NameError: name 'max_sentences' is not defined
