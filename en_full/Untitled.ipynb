# %%
import _pickle as cPickle

dict_tf_idf_key_val = cPickle.load(open('tf_idf_key_val.pkl', 'rb'))
dict_tf_idf_key_val
# Out:
# {'area': {'city centre': {'center': (5.405893581815568,
#     3.201663905898711,
#     897),
#    'centre': (6.765104348707923, 3.641322081788748, 6374),
#    'city': (6.854937260823455, 3.6871377650203847, 7256)}},
#  'customer rating': {'1 out of 5': {'1': (8.21917304260384,
#     7.976954402548457,
#     2893),
#    'one': (4.474487630719272, 3.3184637740278, 234),
#    'poor': (7.684638298686218, 5.027867861890264, 94)},
#   '3 out of 5': {'3': (6.210096871613177, 8.418791069866296, 2862),
#    'three': (6.908367434347542, 4.311836176909032, 198)},
#   '5 out of 5': {'5': (6.741433068581617, 4.073940922258398, 6160),
#    'excellent': (3.957544761361501, 4.119788415519326, 111),
#    'five': (4.7314227289326425, 3.959136302894547, 339)},
#   'average': {'an': (6.192932817164861, 3.6156041279093767, 2792),
#    'average': (6.453658356079299, 5.725952642714718, 4067),
#    'averagely': (4.518986118484691, 3.401592372714891, 51),
# ...

# %%
tf_idf_key_val = {}
tf_idf_key_val['customer rating'] = dict_tf_idf_key_val['customer rating']
print(tf_idf_key_val)
del tf_idf_key_val['customer rating']['high']['25']
tf_idf_key_val
# Out:
# {'customer rating': {'5 out of 5': {'5': (6.741433068581617, 4.073940922258398, 6160), 'five': (4.7314227289326425, 3.959136302894547, 339), 'excellent': (3.957544761361501, 4.119788415519326, 111)}, 'low': {'low': (6.422993917879379, 5.207746132306916, 3891), 'poor': (7.275959358417602, 3.352425942122018, 70), 'one': (4.745589733807547, 4.3934174767691365, 346), 'poorly': (7.256012332824121, 4.49989626939671, 69), 'Low': (4.683046353519854, 5.4314187180659665, 61)}, 'high': {'high': (6.166362506613886, 3.335294060659604, 2687), '25': (8.710389078205544, 4.249013829976876, 1021), 'highly': (5.307238402552802, 5.316377448673587, 778), 'between': (3.9999337773490025, 3.508616587098275, 118), 'ranging': (4.233580680369747, 3.7814650652024446, 79)}, 'average': {'an': (6.192932817164861, 3.6156041279093767, 2792), 'average': (6.453658356079299, 5.725952642714718, 4067), 'averagely': (4.518986118484691, 3.401592372714891, 51), 'three': (7.0389976437335084, 4.073750030382956, 223)}, '3 out 
# ...

# %%
tf_idf_key_val = {
    'customer rating': {
        '1 out of 5': {
            '1': (8.21917304260384, 7.976954402548457, 2893),
            'one': (4.474487630719272, 3.3184637740278, 234),
            'poor': (7.684638298686218, 5.027867861890264, 94)},
        '3 out of 5': {
            '3': (6.210096871613177, 8.418791069866296, 2862),
            'three': (6.908367434347542, 4.311836176909032, 198)},
        '5 out of 5': {
            '5': (6.741433068581617, 4.073940922258398, 6160),
            'excellent': (3.957544761361501, 4.119788415519326, 111),
            'five': (4.7314227289326425, 3.959136302894547, 339)},
        'average': {
            'an': (6.192932817164861, 3.6156041279093767, 2792),
            'average': (6.453658356079299, 5.725952642714718, 4067),
            'averagely': (4.518986118484691, 3.401592372714891, 51),
            'three': (7.0389976437335084, 4.073750030382956, 223)},
        'high': {
            'between': (3.9999337773490025, 3.508616587098275, 118),
            'high': (6.166362506613886, 3.335294060659604, 2687),
            'highly': (5.307238402552802, 5.316377448673587, 778),
            'ranging': (4.233580680369747, 3.7814650652024446, 79)},
        'low': {
            'Low': (4.683046353519854, 5.4314187180659665, 61),
            'low': (6.422993917879379, 5.207746132306916, 3891),
            'one': (4.745589733807547, 4.3934174767691365, 346),
            'poor': (7.275959358417602, 3.352425942122018, 70),
            'poorly': (7.256012332824121, 4.49989626939671, 69)}},
    'eatType': {
        'pub': {
            'Pub': (5.784732127008491, 7.822963306602796, 203),
            'pub': (6.736577574463689, 7.806432684943734, 6117)},
        'restaurant': {
            'restaurant': (6.267029866424083, 5.0885889800626165, 3107)}},
    'familyFriendly': {
        'no': {
            'No': (3.667067045498751, 3.7041215866783643, 73),
            'Not': (4.288769026355144, 3.78793092458872, 179),
            'adult': (4.868282896871475, 3.882356922720232, 413),
            'adults': (4.565932835217415, 3.872059019047474, 267),
            'allow': (3.5649493348382366, 3.663732972710925, 63),
            'allowed': (3.7643553522558304, 3.7657009454142067, 84),
            'no': (4.550178812063948, 3.31451812940601, 261),
            'non': (5.159878592300073, 4.040604498743776, 629),
            'not': (6.615417378498045, 3.7544420478838045, 5136)}},
    'food': {
        'Chinese': {
            'Chinese': (9.07200984445518, 15.722885907426601, 2887)},
        'English': {
            'British': (6.576678732844249, 12.017761745121355, 245),
            'English': (7.923328649693951, 12.441014110733812, 3135),
            'breakfast': (6.977974196467856, 12.020392298777018, 121),
            'traditional': (7.61129794983735, 9.95369796677615, 58)},
        'Fast food': {
            'American': (7.850543561654984, 6.778505333876271, 68),
            'Fast': (12.486583336861932, 7.287966790569617, 1483),
            'burger': (7.503818137314756, 7.195184044105724, 54),
            'fast': (7.060634584887453, 7.169549899214677, 3401),
            'fries': (8.305197388516888, 6.886776238636356, 92),
            'joint': (3.637979679208801, 6.017477695189973, 70)},
        'French': {
            'French': (9.507211912052583, 6.994454984656095, 4439),
            'cheese': (9.02027142463785, 7.2225103567588596, 148),
            'drinks': (4.351335185837775, 3.6530597109394782, 53),
            'fine': (3.988796234632465, 4.282391206236515, 64),
            'wine': (10.011126835782123, 6.733794787829509, 286)},
        'Indian': {
            'Indian': (8.204229520181993, 8.568173335376452, 4321)},
        'Italian': {
            'Italian': (9.58482941410307, 7.30000676069, 4793),
            'pasta': (8.587575322005371, 7.062063896698085, 111)},
        'Japanese': {
            'Japanese': (11.371327526462782, 6.99891507138567, 4651),
            'Sushi': (7.503818137314756, 7.596361090234896, 54),
            'bar': (3.483308355755223, 4.117892712214877, 56),
            'sushi': (11.13803674168861, 7.0773234622623, 605)}},
    'priceRange': {
        'cheap': {
            'cheap': (6.24481461520699, 7.560956441787627, 3009),
            'inexpensive': (4.790015510113396, 4.252220323884765, 160)},
        'high': {
            'end': (4.0057831553579994, 4.320492030849973, 119),
            'expensive': (5.228043173877735, 4.3091442892554905, 694),
            'high': (6.361953084659037, 3.9362753137947712, 3563),
            'higher': (4.744368576708243, 3.4760268125838922, 151)},
        'less than £20': {
            '20': (6.20058652363662, 4.181431442945742, 2823),
            'Low': (3.888534220154669, 4.2340110684119185, 51),
            'below': (5.70141847353496, 6.548441795908248, 66),
            'inexpensive': (4.945992673511404, 3.7918471636744915, 195),
            'less': (6.137658294051513, 7.2787550786590565, 2578),
            'lower': (3.507631805144532, 5.106977105689956, 58),
            'pounds': (7.0389976437335084, 3.0349870403595562, 223),
            'than': (6.120509069673471, 3.8778562399862566, 2515),
            'under': (7.0681660549791, 7.062664555538233, 229)},
        'moderate': {
            'medium': (4.307865197747856, 4.2409607156858, 184),
            'mid': (5.208393260280585, 3.6671945604038356, 272),
            'moderate': (6.154918165610933, 6.861923091562168, 2643),
            'moderately': (5.799177865872709, 5.998293984077968, 1582),
            'pricing': (3.730536587522731, 3.6941283389284636, 80)},
        'more than £30': {
            '30': (8.136359244853681, 8.315634773410768, 2643),
            'above': (4.823777252063054, 6.994214627544907, 167),
            'costing': (3.976230890818516, 3.5182171805370315, 57),
            'costs': (4.197869704755175, 4.1332160284289605, 157),
            'euros': (5.827111091289664, 3.4664555135080026, 74),
            'expensive': (4.969595464938777, 3.0779568732823144, 478),
            'higher': (4.912963452188227, 4.464274028338636, 187),
            'more': (6.0182382280766085, 7.993316060525133, 2170),
            'over': (5.086368750706816, 7.643378260640392, 233),
            'than': (6.012142471858194, 3.738977365418068, 2151)},
        '£20-25': {
            '20': (5.993857736578839, 4.09275623796468, 2095),
            '20-£25': (8.630717507529527, 9.670053773944943, 186),
            'around': (3.6478117189607473, 4.4606291715424815, 71),
            'between': (5.261630848091503, 9.343555751693836, 291),
            'from': (4.689273138844542, 4.036644175812623, 319),
            'mid': (4.958030424287081, 3.552954486195588, 198),
            'ranging': (3.957544761361501, 5.737481094292899, 111)
        }}}

# %%
features_value_dict = {}
for feature, value_term_map in tf_idf_key_val.items():
    value_dict = {}
    for value, term_map in value_term_map.items():
        term_idx_map = {}
        for idx, (term, scores) in enumerate(term_map.items()):
            term_idx_map[term] = idx
        value_dict[value] = term_idx_map
    features_value_dict[feature] = value_dict

print(features_value_dict)
cPickle.dump(features_value_dict, open('featuee_value_idx.pkl', 'wb'))
# Out:
# {'customer rating': {'1 out of 5': {'1': 0, 'one': 1, 'poor': 2}, '3 out of 5': {'3': 0, 'three': 1}, '5 out of 5': {'5': 0, 'excellent': 1, 'five': 2}, 'average': {'an': 0, 'average': 1, 'averagely': 2, 'three': 3}, 'high': {'between': 0, 'high': 1, 'highly': 2, 'ranging': 3}, 'low': {'Low': 0, 'low': 1, 'one': 2, 'poor': 3, 'poorly': 4}}, 'eatType': {'pub': {'Pub': 0, 'pub': 1}, 'restaurant': {'restaurant': 0}, 'familyFriendly': {'no': 0}}, 'food': {'Chinese': {'Chinese': 0}, 'English': {'British': 0, 'English': 1, 'breakfast': 2, 'traditional': 3}, 'Fast food': {'American': 0, 'Fast': 1, 'burger': 2, 'fast': 3, 'fries': 4, 'joint': 5}, 'French': {'French': 0, 'cheese': 1, 'drinks': 2, 'fine': 3, 'wine': 4}, 'Indian': {'Indian': 0}, 'Italian': {'Italian': 0, 'pasta': 1}, 'Japanese': {'Japanese': 0, 'Sushi': 1, 'bar': 2, 'sushi': 3}}, 'priceRange': {'cheap': {'cheap': 0, 'inexpensive': 1}, 'high': {'end': 0, 'expensive': 1, 'high': 2, 'higher': 3}, 'less than £20': {'20': 0, 'Low': 
# ...

# %%
import csv
from collections import Counter, defaultdict

headers = ['name','eatType','priceRange', 'customer rating', 'near', 'food', 'area','familyFriendly']

ifile = open('trainset.csv', encoding='utf-8', mode='rt')

trainset_reader = csv.DictReader(ifile)

name_tok = 'XNAMEX'
near_tok = 'XNEARX'
food_tok = 'XFOODX'
feature_list = []
sentences = []
foods = set()
value_counts = defaultdict(lambda: Counter())
value_in_sent_count = defaultdict(lambda: Counter())
for row in trainset_reader:
    i1 = row['mr']
    i2 = row['ref']
    kv = {}
    keywords = i1.split(',')
    for keyword in keywords:
        kidx = keyword.find('[')
        key = keyword[:kidx].strip()
        value = keyword[kidx + 1: keyword.find(']')]
        kv[key] = value
        if key == 'name':
            i2 = i2.replace(value, name_tok)
            value = name_tok
        if key == 'near':
            i2 = i2.replace(value, near_tok)
            value = near_tok
            
        value_counts[key][value] += 1
        if value.replace(' ', '').lower() in i2.replace(' ', '').lower():
            value_in_sent_count[key][value] += 1
        if False:
            if key == 'priceRange' and value in ['more than £30', 'less than £20', '£20-25']:
                if value == 'more than £30' and 'more' in i2.lower() or '30' in i2.lower():
                    value_in_sent_count[key][value] += 1
                if value == 'less than £20' and 'less' in i2.lower() or '20' in i2.lower():
                    value_in_sent_count[key][value] += 1
                if value == '£20-25' and 'range' in i2.lower() and '30' in i2.lower():
                    value_in_sent_count[key][value] += 1
        
    feature_list.append(kv)
    sentences.append(i2)

ifile.close()
value_counts
# Out:
# defaultdict(<function __main__.<lambda>>,
#             {'area': Counter({'city centre': 7822, 'riverside': 16894}),
#              'customer rating': Counter({'1 out of 5': 4282,
#                       '3 out of 5': 4039,
#                       '5 out of 5': 4798,
#                       'average': 5495,
#                       'high': 4264,
#                       'low': 5212}),
#              'eatType': Counter({'coffee shop': 10396,
#                       'pub': 6531,
#                       'restaurant': 3184}),
#              'familyFriendly': Counter({'no': 8731, 'yes': 17564}),
#              'food': Counter({'Chinese': 2929,
#                       'English': 4100,
#                       'Fast food': 5891,
#                       'French': 5889,
#                       'Indian': 4412,
#                       'Italian': 5909,
#                       'Japanese': 5996}),
#              'name': Counter({'XNAMEX': 42061}),
#              'near': Counter({'XNEARX': 20546}),
# ...

# %%
value_in_sent_count
# Out:
# defaultdict(<function __main__.<lambda>>,
#             {'area': Counter({'city centre': 6396, 'riverside': 12879}),
#              'customer rating': Counter({'1 out of 5': 2691,
#                       '3 out of 5': 2616,
#                       '5 out of 5': 2876,
#                       'average': 4134,
#                       'high': 3468,
#                       'low': 3868}),
#              'eatType': Counter({'coffee shop': 9865,
#                       'pub': 6234,
#                       'restaurant': 3070}),
#              'familyFriendly': Counter({'no': 6294, 'yes': 447}),
#              'food': Counter({'Chinese': 2885,
#                       'English': 3134,
#                       'Fast food': 4681,
#                       'French': 4422,
#                       'Indian': 4319,
#                       'Italian': 4777,
#                       'Japanese': 4643}),
#              'name': Counter({'XNAMEX': 42033}),
#              'near': Counter({'XNEARX': 20308}),
# ...

# %%
for key, value_count in sorted(value_counts.items()):
    for value, count in value_count.items():
        sent_count = value_in_sent_count[key].get(value, 0)
        print('{}\t{}\t{}'.format(key, value, sent_count/count))
# Out:
# area	riverside	0.7623416597608619
# area	city centre	0.8176936844796727
# customer rating	5 out of 5	0.5994164235097957
# customer rating	low	0.7421335379892555
# customer rating	high	0.8133208255159474
# customer rating	average	0.7523202911737944
# customer rating	3 out of 5	0.6476850705620203
# customer rating	1 out of 5	0.6284446520317608
# eatType	pub	0.9545245751033532
# eatType	coffee shop	0.948922662562524
# eatType	restaurant	0.9641959798994975
# familyFriendly	yes	0.02544978364837167
# familyFriendly	no	0.7208796243271103
# food	English	0.764390243902439
# food	Japanese	0.774349566377585
# food	French	0.7508914926133469
# food	Fast food	0.7946019351553216
# food	Italian	0.8084278219664918
# food	Indian	0.978921124206709
# food	Chinese	0.9849778081256402
# name	XNAMEX	0.9993343001830675
# near	XNEARX	0.9884162367370778
# priceRange	more than £30	0.3464650766609881
# priceRange	cheap	0.7354823417871533
# priceRange	less than £20	0.3584939650513421
# ...

# %%
flen = []
for key, value_form in tf_idf_key_val.items():
    for value, form_score in value_form.items():
        formulations = [x[0] for x in sorted(form_score.items(), key= lambda x: x[1][-1], reverse=True)]
        for formulation, score in form_score.items():
            pass
            #print('{}\t{}\t{}\t{}'.format(key, value, formulation, score[-1]))
        oline = ', '.join(formulations)
        flen.append(len(formulations))
        print('{}\t{}\t{}'.format(key, value, oline))

sum(flen)/len(flen)
# Out:
# customer rating	1 out of 5	1, one, poor
# customer rating	3 out of 5	3, three
# customer rating	5 out of 5	5, five, excellent
# customer rating	average	average, an, three, averagely
# customer rating	high	high, highly, between, ranging
# customer rating	low	low, one, poor, poorly, Low
# eatType	pub	pub, Pub
# eatType	restaurant	restaurant
# familyFriendly	no	not, non, adult, adults, no, Not, allowed, No, allow
# food	Chinese	Chinese
# food	English	English, British, breakfast, traditional
# food	Fast food	fast, Fast, fries, joint, American, burger
# food	French	French, wine, cheese, fine, drinks
# food	Indian	Indian
# food	Italian	Italian, pasta
# food	Japanese	Japanese, sushi, bar, Sushi
# priceRange	cheap	cheap, inexpensive
# priceRange	high	high, expensive, higher, end
# priceRange	less than £20	20, less, than, under, pounds, inexpensive, below, lower, Low
# priceRange	moderate	moderate, moderately, mid, medium, pricing
# ...
